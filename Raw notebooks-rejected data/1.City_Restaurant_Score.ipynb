# %%
import pandas as pd
import os
citydata_raw = pd.read_csv("Restaurant_Scores_-_Lives_Standard.csv")
citydata_raw.head(1)
# Out:
#    business_id            business_name  business_address  business_city  \
# 0        69618  Fancy Wheatfield Bakery  1362 Stockton St  San Francisco
#
#   business_state business_postal_code  business_latitude  business_longitude  \
# 0             CA                94133                NaN                 NaN
#
#   business_location  business_phone_number   inspection_id  \
# 0               NaN                    NaN  69618_20190304
#
#           inspection_date  inspection_score inspection_type  \
# 0  03/04/2019 12:00:00 AM               NaN       Complaint
#
#             violation_id                     violation_description  \
# 0  69618_20190304_103130  Inadequate sewage or wastewater disposal
#
#    risk_category
# 0  Moderate Risk

# %%
citydata = citydata_raw.loc[:,["business_id", "business_name", "business_address", 
                           "business_city", "business_state", "business_postal_code"]]
citydata.head(5)
# Out:
#    business_id            business_name  business_address  business_city  \
# 0        69618  Fancy Wheatfield Bakery  1362 Stockton St  San Francisco
# 1        97975               BREADBELLY   1408 Clement St  San Francisco
# 2        69487   Hakkasan San Francisco       1 Kearny St  San Francisco
# 3        91044    Chopsticks Restaurant   4615 Mission St  San Francisco
# 4        85987                  Tselogs      552 Jones St  San Francisco
#
#   business_state business_postal_code
# 0             CA                94133
# 1             CA                94118
# 2             CA                94108
# 3             CA                94112
# 4             CA                94102

# %%
citydata= citydata.drop_duplicates()
citydata.head(100)
# Out:
#      business_id                business_name        business_address  \
# 0          69618      Fancy Wheatfield Bakery        1362 Stockton St
# 1          97975                   BREADBELLY         1408 Clement St
# 2          69487       Hakkasan San Francisco             1 Kearny St
# 3          91044        Chopsticks Restaurant         4615 Mission St
# 4          85987                      Tselogs            552 Jones St
# ..           ...                          ...                     ...
# 100       100017  AMICI'S EAST COAST PIZZERIA             475 06th St
# 101        84971                     Cafe Med             201 Pine St
# 102        90428                   McDonald's          609 Market St.
# 103        95410                  Bowl'D Acai               428 11 St
# 104        95455             Bake Cheese Tart  845 Market St #16, LL1
#
#      business_city business_state business_postal_code
# 0    San Francisco             CA                94133
# ...

# %%
citydata.count()
# Out:
# business_id             6253
# business_name           6253
# business_address        6253
# business_city           6253
# business_state          6253
# business_postal_code    6059
# dtype: int64

# %%
citydata_id = citydata_raw.loc[:,["business_id"]]

# %%
citydata_id_new = citydata_id.drop_duplicates()

# %%
citydata_id_new.count()
# Out:
# business_id    6253
# dtype: int64

# %%
citydata.to_csv("Restaurant_Score_Output.csv")
